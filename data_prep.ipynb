# %%
import pandas as pd
import spacy
import string
import re
from spacy.lang.en.stop_words import STOP_WORDS

from flashtext import KeywordProcessor
from spacy.matcher import PhraseMatcher
import sys

#progress bar packages
from tqdm import tqdm
#ngram package
from nltk.util import ngrams
from nltk.tokenize import RegexpTokenizer
import nltk
nlp = spacy.load("en_core_web_lg")

# %%
df = pd.read_csv("indeed_jd.csv")
df.head()
# Out:
#         Job Type                                       Job_Title  \
# 0  Data engineer                                   Data Engineer
# 1  Data engineer                                   Data Engineer
# 2  Data engineer  Production Support Engineer - Data Engineering
# 3  Data engineer                                   Data Engineer
# 4  Data engineer                                   Data Engineer
#
#                                          Description
# 0  Responsibilities\nBuild, maintain the data pip...
# 1  What to Expect\nTesla Electronics Test and Aut...
# 2  Bonhill Partners Singapore\nPosted 5 days ago ...
# 3  Beyond Limits is a pioneering Artificial Intel...
# 4  Trusted carbon credits. Real impact.\nClimate ...

# %%
df.dtypes
# Out:
# Job Type       object
# Job_Title      object
# Description    object
# dtype: object

# %%
#preprocessing
def preprocess_jd(text):
    
    # Lowercase the text
    text = text.lower()
    #remove stop words
    text = text = ' '.join([word for word in text.split() if word.lower() not in STOP_WORDS])
    # Check if any of the patterns .\n, \n\n, \n is present and replace accordingly
    if '.\n' in text:
        text = text.replace('.\n', '. ')
    elif '\n\n' in text:
        text = text.replace('\n\n', ' ')
    elif '\n' in text:
        text = text.replace('\n', '. ')
    # Process the text using SpaCy
    doc = nlp(text)

    # Extract sentences from the processed text and remove trailing full stops
    sentences = [sent.text.strip('. ') for sent in doc.sents]
    # remove special chracters except those that useually used in hard skill
    special_char = ['#', '+']
    sentences = [re.sub(r'[^a-zA-Z0-9{}]+'.format(re.escape(' '.join(special_char))), ' ', sent) for sent in sentences]
    #remove double spacing
    sentences = [re.sub(r'\s+', ' ', sent) for sent in sentences]
    
    return sentences

# %%
df["clean_jd"] = df["Description"].apply(preprocess_jd)
df
# Out:
#               Job Type                                          Job_Title  \
# 0        Data engineer                                      Data Engineer
# 1        Data engineer                                      Data Engineer
# 2        Data engineer     Production Support Engineer - Data Engineering
# 3        Data engineer                                      Data Engineer
# 4        Data engineer                                      Data Engineer
# ...                ...                                                ...
# 1023  Machine learning                           Software Engineer Intern
# 1024  Machine learning                                       AI Developer
# 1025  Machine learning                 Biostatistician, Population Health
# 1026  Machine learning  Senior/ Research Scientist (High Performance C...
# 1027  Machine learning  Research Assistant/ Associate on Dialogue Summ...
#
#                                             Description  \
# 0     Responsibilities\nBuild, maintain the data pip...
# 1     What to Expect\nTesla Electronics Test and Aut...
# 2     Bonhill Partners Singapore\nPosted 5 days ago ...
# 3     Beyond Limits is a pioneering Artificial Intel...
# 4     Trusted carbon credits. Real impact.\nClimate ...
# ...                                                 ...
# 1023  About us\nFairmart is an early-stage community...
# 1024  Responsibilities:\nWe are working on exciting ...
# 1025  The Singapore Eye Research Institute (SERI) se...
# 1026  What the role is\n\nThe Centre for Climate Res...
# 1027  Description\nDialogue summarization is the tas...
#
#                                                clean_jd
# 0     [responsibilities build maintain data pipeline...
# 1     [expect tesla electronics test automation grou...
# 2     [bonhill partners singapore posted 5 days ago ...
# 3     [limits pioneering artificial intelligence eng...
# 4     [trusted carbon credits, real impact, climate ...
# ...                                                 ...
# 1023  [fairmart early stage community commerce compa...
# 1024  [responsibilities working exciting new ai powe...
# 1025  [singapore eye research institute seri serves ...
# 1026  [role centre climate research singapore ccrs d...
# 1027  [description dialogue summarization task synth...
#
# [1028 rows x 4 columns]

# %%
df1 = pd.DataFrame({
    'jd': df['Description'].repeat(df['clean_jd'].apply(len)),
    'sentence': [sent for sublist in df['clean_jd'] for sent in sublist]
})
df1
# Out:
#                                                      jd  \
# 0     Responsibilities\nBuild, maintain the data pip...
# 0     Responsibilities\nBuild, maintain the data pip...
# 0     Responsibilities\nBuild, maintain the data pip...
# 0     Responsibilities\nBuild, maintain the data pip...
# 0     Responsibilities\nBuild, maintain the data pip...
# ...                                                 ...
# 1027  Description\nDialogue summarization is the tas...
# 1027  Description\nDialogue summarization is the tas...
# 1027  Description\nDialogue summarization is the tas...
# 1027  Description\nDialogue summarization is the tas...
# 1027  Description\nDialogue summarization is the tas...
#
#                                                sentence
# 0     responsibilities build maintain data pipelines...
# 0     data warehouse models sync data source changes...
# 0     existing data setup keeping abreast changes ad...
# 0     identify root cause data inconsistencies proce...
# 0     care deployments code repository maintenance n...
# ...                                                 ...
# 1027  ra position aims evaluate recent efforts takin...
# 1027  preferred bachelor s master s degree computer ...
# 1027  ijcai 2022 liu chen controllable neural dialog...
# 1027  emnlp ijcnlp 2019 xiyan fu yating zhang tianyi...
# 1027  acl ijcnlp 2021 supervision nancy chen institu...
#
# [17602 rows x 2 columns]

# %%
emsi = pd.read_csv("all_emsi_skills.csv")
emsi.head()
# Out:
#             type                    id  \
# 0  Certification  KS120P86XDXZJT3B7KVJ
# 1     Hard Skill  KS126XS6CQCFGC3NG79X
# 2     Hard Skill  KS1200B62W5ZF38RJ7TD
# 3     Hard Skill  KS126XW78QJCF4TRV2X7
# 4     Hard Skill  KS126XY68BNKXSBSLPYS
#
#                                            name
# 0  (American Society For Quality) ASQ Certified
# 1                               .NET Assemblies
# 2                                .NET Framework
# 3                              .NET Framework 1
# 4                              .NET Framework 3

# %%
emsi_hard = emsi.loc[emsi['type'] == "Hard Skill"]
emsi_hard
# Out:
#              type                    id                     name
# 1      Hard Skill  KS126XS6CQCFGC3NG79X          .NET Assemblies
# 2      Hard Skill  KS1200B62W5ZF38RJ7TD           .NET Framework
# 3      Hard Skill  KS126XW78QJCF4TRV2X7         .NET Framework 1
# 4      Hard Skill  KS126XY68BNKXSBSLPYS         .NET Framework 3
# 5      Hard Skill  KS126XR63RKYVCKYDNBN         .NET Framework 4
# ...           ...                   ...                      ...
# 29072  Hard Skill  KS125T770BQ1N7T35WW0                     cURL
# 29073  Hard Skill  ESB66C176361E21016FE     eClinicalWorks (ECW)
# 29074  Hard Skill  KS123KB73N41KLG2QH44  eNodeB (LTE Technology)
# 29075  Hard Skill  KSEPVMUZUEDHVWQBO8UN         iBeacon Protocol
# 29076  Hard Skill  ESCD425835A01B0C6EE7                pH Meters
#
# [27031 rows x 3 columns]

# %%
def extract_and_remove_bracketed_words(text_list):
    cleaned_list = []
    bracketed_words = set() 

    for text in text_list:
        # Define a regular expression pattern to match words in brackets
        pattern = r'[\(\[]([^()\[\]]+)[\)\]]'

        # Find all bracketed words in the text
        found_words = re.findall(pattern, text)

        # Remove the bracketed words from the original text
        cleaned_text = re.sub(pattern, '', text)

        # Append the cleaned text and extracted bracketed words to lists
        cleaned_list.append(cleaned_text.strip())

        # Append non-empty bracketed words to the list
        if found_words:
            bracketed_words.update(found_words)

    return cleaned_list+list(bracketed_words)

skill_list = extract_and_remove_bracketed_words(emsi_hard["name"].values)
skill_list
# Out:
# ['.NET Assemblies',
#  '.NET Framework',
#  '.NET Framework 1',
#  '.NET Framework 3',
#  '.NET Framework 4',
#  '.NET Reflector',
#  '.NET Remoting',
#  '.nettiers',
#  '10 Gigabit Ethernet',
#  '1010data',
#  '10BASE-F',
#  '10BASE-FL',
#  '10BASE2',
#  '10BASE5',
#  '10G-PON',
#  '123RF',
#  '128bit',
#  '12factor',
#  '2020 Design Software',
#  '2D Animation',
#  '2D Computer Graphics',
#  '2D Gel Analysis Software',
#  '2checkout',
#  '3.5G',
#  '35 Mm Films',
#  '389 Directory Server',
#  '3CX Phone Systems',
#  '3D Art',
#  '3D Camcorder',
#  '3D Computer Graphics',
#  '3D Computer Graphics Software',
#  '3D Conformal Radiotherapy',
#  '3D Graphic Design',
#  '3D Modeling',
#  '3D Modeling Softwares',
#  '3D Printing',
#  '3D Projection',
#  '3D Reconstruction',
#  '3D Rendering',
#  '3D Scanning',
#  '3D Visualization',
#  '3DML',
#  '3DMark',
#  '3DSlicer',
#  '3Delight',
#  '3Dvia Composer',
#  '3GP',
#  '3GPP',
#  '3GPP2',
#  '3d Engine',
#  '3d Secure',
#  '3d Solid And Surface Modeling',
#  '4D Modelling',
#  '4DOS',
#  '4Sight',
#  '4d Database',
#  '50% Tissue Culture Infective Dose',
#  '529 College Savings Planning',
#  '56 Kbit/S Modems',
#  '64-Bit Power PC Processors',
#  '64bit',
#  '6LoWPAN',
#  '7-Zip',
#  '8 Mm Video Format',
#  '90nm CMOS',
#  '960.gs',
#  'A-Files Accountability And Control Systems',
#  'A/B Testing',
#  'A3 Problem Solving Techniques',
#  'A431 Cells',
#  'AAA Protocol',
#  'AAA Server',
#  'ABC FlowCharter',
#  'ABEC Scale',
#  'ABI Solid Sequencing',
#  'ABINIT',
#  'ABL Radiometers',
#  'ABR Routers',
#  'AC Power Plugs And Sockets',
#  'AC3D',
#  'ACCOL Workbench',
#  'ACDSee',
#  'ACID Pro',
#  'ACL2',
#  'AD Model Builder',
#  'ADABAS',
#  'ADATE Systems',
#  'ADHM Construction',
#  'ADMS',
#  'ADO.NET',
#  'ADO.NET Data Services',
#  'ADODC Class',
#  'ADOMD.NET',
#  'ADOdb Database Abstraction Library For PHP',
#  'ADP Enterprise',
#  'ADP Reporting',
#  'ADP SmartCompliance',
#  'ADP TotalSource',
#  'ADP Vantage',
#  'ADP Workforce Now',
#  'ADT Security Services',
#  'AEP Netilla Secure Remote Access',
#  'AERMOD',
#  'AERONET',
#  'AES3',
#  'AFGROW',
#  'AFP Conversion And Indexing Facility',
#  'AGFA Impax 6',
#  'AGi32',
#  'AISC 360 Specification For Structural Steel Buildings',
#  'AKTA',
#  'ALGOL',
#  'ALMSA',
#  'ALT Linux',
#  'ALTernate Queueing',
#  'ALWD Citation Manual',
#  'AMAP',
#  'AMD Catalyst',
#  'AMD CrossFireX',
#  'AME Accounting Software',
#  'AMPAC',
#  'AMPL',
#  'AMS Device Management',
#  'AMT Asset Management Software',
#  'AN/PRC-148 Multiband Inter/Intra Team Radio',
#  'ANSI C',
#  'ANSI Escape Codes',
#  'ANSI/ANS Standards',
#  'ANSI/ASME Y14.1 Standards',
#  'ANSYS Meshing',
#  'ANTLR',
#  'AOLserver',
#  'AP Stylebook',
#  'APC Smart-UPS',
#  'API Design',
#  'API Gateway',
#  'API Management',
#  'API Oil-Water Separator',
#  'API Writer',
#  'APL',
#  'APPX',
#  'APache EXtenSion Tool',
#  'AQtime',
#  'AR System Administration',
#  'ARC Macro Language',
#  'ARCserve Backup Solutions',
#  'AREMOS',
#  'ARINC Standards',
#  'ARM Architecture',
#  'ARM Architecture Microprocessors',
#  'ARM Microarchitectures',
#  'ARM7 Architecture',
#  'ARM9 Architecture',
#  'ARMulator',
#  'ARPACK',
#  'ARToolKit',
#  'AS2',
#  'AS4 Conformance Profile',
#  'ASARS-2 Radar System',
#  'ASC X12 Standards',
#  'ASIC Programming Language',
#  'ASME Boiler And Pressure Vessel Code',
#  'ASP.NET',
#  'ASP.NET Extensions For AJAX',
#  'ASP.NET Fundamentals',
#  'ASP.NET MVC Framework',
#  'ASReML',
#  'ASTM B117 - 11 Standard',
#  'AT91SAM',
#  'ATA Over Ethernet',
#  'ATA Packet Interface',
#  'ATL Server',
#  'ATLAS.ti',
#  'ATM Adaptation Layer',
#  'ATM Adaptation Layer 1',
#  'ATM Adaptation Layer 2',
#  'ATM Adaptation Layer 5',
#  'ATM Controllers',
#  'ATi Radeon R200 Series',
#  'ATutor',
#  'AUTomotive Open System Architecture',
#  'AVG',
#  'AVL Tree',
#  'AVR32 Microprocessor',
#  'AVS Video Editor',
#  'AVSnap',
#  'AVoided Emissions And GeneRation Tool',
#  'AWK',
#  'AWS CLI',
#  'AWS Lambda',
#  'AWS SDK',
#  'AWStats',
#  'AX.25 Protocol',
#  'Abacus',
#  'Abaqus',
#  'Abc Analysis',
#  'Abcpdf',
#  'Abdomen',
#  'Abdominal Surgery',
#  'Abdominal Trauma',
#  'Abdominal Ultrasonography',
#  'Abdominoplasty',
#  'Abeel Java Toolkit',
#  'AbiWord',
#  'Abiquo Enterprise Edition',
#  'Ablation',
#  'Able2Extract',
#  'Ableton Live',
#  'Abnormal Psychology',
#  'Abnormal Return',
#  'Aboriginal Law',
#  'Abrasion',
#  'Abrasive Blasting',
#  'Abrasive Saw',
#  'Abscesses',
#  'Absolute Manage',
#  'Absorption',
#  'Absorption Distribution Metabolism And Excretion',
#  'Absorption Refrigeration',
#  'Absorption Spectroscopy',
#  'Abstract Algebra',
#  'Abstract Class',
#  'Abstract Data Types',
#  'Abstract Factory Pattern',
#  'Abstract Management',
#  'Abstract State Machine Language',
#  'Abstract Syntax Notation One',
#  'Abstract Syntax Tree',
#  'Abstract User Interface Markup Language',
#  'Abstract Window Toolkit',
#  'Abstraction Layers',
#  'Abstractions',
#  'Abtest',
#  'Abutments',
#  'Academic Achievement',
#  'Academic History',
#  'Academic Integrity',
#  'Academic Standards',
#  'Academic Studies',
#  'Academic Writing',
#  'Acceleo',
#  'Accelerated Failure Time Models',
#  'Accelerated Life Testing',
#  'Accelerated Math',
#  'Accelerator Physics',
#  'Accelerometer',
#  'Accelrys',
#  'Accent Reduction',
#  'Acceptable Use Policy',
#  'Acceptance Sampling',
#  'Acceptance Test Procedures',
#  'Acceptance Test-Driven Development',
#  'Acceptance Testing',
#  'Access Control Facility',
#  'Access Control List',
#  'Access Control Matrix',
#  'Access Controls',
#  'Access Keys',
#  'Access Link Control Application Part',
#  'Access Method',
#  'Access Modifiers',
#  'Access Network',
#  'Access Network Discovery And Selection Function',
#  'Access Project',
#  'Access Query Languages',
#  'Access Rules',
#  'Access Stratum',
#  'Accession Commitments Database',
#  'Accessioning',
#  'Accident Analysis',
#  'Accident Response Group',
#  'Acclimatization',
#  'Accord.net',
#  'Accordion',
#  'Account Aggregation',
#  'Account Analysis',
#  'Account Development',
#  'Account Growth',
#  'Account Management',
#  'Account Planning',
#  'Accountancy And Passenger Ticket Issuing System',
#  'Accounting',
#  'Accounting Ethics',
#  'Accounting Information Systems',
#  'Accounting Machines',
#  'Accounting Management',
#  'Accounting Methods',
#  'Accounting Records',
#  'Accounting Research',
#  'Accounting Softwares',
#  'Accounting Systems',
#  'Accounts Payable',
#  'Accounts Payable Automation',
#  'Accounts Payable Fundamentals',
#  'Accounts Receivable',
#  'Accounts Receivable Management',
#  'Accounts Receivable/Billing Fundamentals',
#  'Accreditation Of Public Relations',
#  'Accredited Investment Fiduciary',
#  'Accrisoft Freedom',
#  'Accrual Accounting',
#  'Accruals',
#  'Accrued Liabilities',
#  'AccuRev SCM',
#  'AceProject',
#  'Achartengine',
#  'Achievement Testing',
#  'Acid Hydrolysis',
#  'Acid Leaching',
#  'Acids',
#  'Acoustic Control Induction Systems',
#  'Acoustic Doppler Current Profiler',
#  'Acoustic Emission',
#  'Acoustic Guitar',
#  'Acoustic Suspension',
#  'Acoustical Engineering',
#  'Acoustical Intelligence',
#  'Acoustics',
#  'Acquisition Due Diligence',
#  'Acquisition Life Cycle Framework',
#  'Acquisition Processes',
#  'Acrochordon',
#  'Acromioplasty',
#  'Acronis True Image',
#  'Act! CRM',
#  'Actel SmartFusion',
#  'Acting',
#  'Acting Workshop',
#  'Action Button',
#  'Action Filter',
#  'Action Research',
#  'ActionScript',
#  'Actioncontroller',
#  'Actionform',
#  'Actionlink',
#  'Actionview',
#  'Activated Sludge Treatment',
#  'Activation Systems Development',
#  'Active Database Management Systems',
#  'Active Directory',
#  'Active Directory Application Mode',
#  'Active Directory Explorer',
#  'Active Directory Federation Services',
#  'Active Directory Lightweight Directory Services',
#  'Active Directory Migration Tool',
#  'Active Directory Rights Management Services',
#  'Active Directory Service Interfaces',
#  'Active Format Description',
#  'Active Fuel Management',
#  'Active Hdl',
#  'Active Input Method Manager',
#  'Active Noise Controls',
#  'Active Queue Management',
#  'Active Record Pattern',
#  'Active Release Techniques',
#  'Active Safety',
#  'Active Scripting',
#  'Active Server Pages',
#  'Active Stretching',
#  'Active Template Library',
#  'Active Treatment',
#  'ActivePerl',
#  'ActivePython',
#  'ActiveReports',
#  'ActiveState Komodo',
#  'ActiveSync',
#  'ActiveVOS',
#  'ActiveX',
#  'ActiveX Data Objects',
#  'ActiveX Data Objects For The Windows CE Operating System',
#  'ActiveX Document',
#  'ActiveXObject',
#  'Activeadmin',
#  'Activeandroid',
#  'Activecollab',
#  'Activepivot',
#  'Activism',
#  'Activiti',
#  'Activities Of  Daily Living',
#  'Activity Diagram',
#  'Activity Manager',
#  'Activity Monitor',
#  'Activity Recognition',
#  'Activity Sequencing',
#  'Activity-Based Costing',
#  'Activity-Based Learning',
#  'Activstudio',
#  'Actor Model',
#  'Actuarial Reserves',
#  'Actuarial Science',
#  'Acumatica',
#  'Acupressure',
#  'Acupuncture',
#  'Acute Assessment Unit',
#  'Acute Care',
#  'Acute Coronary Syndrome',
#  'Acute Medicine',
#  'Acute Renal Failure',
#  'Acute Respiratory Distress Syndrome',
#  'Ad Hoc On-Demand Distance Vector Routing',
#  'Ad Hoc Testing',
#  'Ad Text Optimization',
#  'Ad Tracking',
#  'Ad Valorem Tax',
#  'Ad-Aware',
#  'Ad-Hoc Configuration Protocols',
#  'Ada',
#  'Ada Compliance',
#  'Ada Programming Support Environment',
#  'Adaboost',
#  'Adafruit',
#  'Adaptation Kit Upgrade',
#  'Adapted Physical Education',
#  'Adapter Pattern',
#  'Adapter Scripting Language',
#  'Adapters',
#  'Adaptive Behavior',
#  'Adaptive Bitrate Streaming',
#  'Adaptive Communication Environments',
#  'Adaptive Control',
#  'Adaptive Design',
#  'Adaptive Differential Pulse-Code Modulation',
#  'Adaptive Equalizer',
#  'Adaptive Equipment',
#  'Adaptive Filter',
#  'Adaptive Insights',
#  'Adaptive Learning',
#  'Adaptive Neuro Fuzzy Inference Systems',
#  'Adaptive Optics',
#  'Adaptive Reuse',
#  'Adcolony',
#  'Addiction Medicine',
#  'Additive Increase/Multiplicative Decrease',
#  'Additive Manufacturing',
#  'Additives',
#  'Address Locator',
#  'Address Resolution Protocols',
#  'Address Space Layout Randomization',
#  'Addressing Modes',
#  'Addressing Schemes',
#  'Addthis',
#  'Adempiere',
#  'Adenoidectomy',
#  'Adhearsion',
#  'Adhesive Bonding',
#  'Adhesive Capsulitis Of Shoulder',
#  'Adhoc Queries',
#  'Adipose Tissue',
#  'Adium',
#  'Adjacency Matrix',
#  'Adjacent Channel Power Ratios',
#  'Adjudication Process',
#  'Adjustable Gastric Band',
#  'Adjusted Gross Income',
#  'Adjusting Entries',
#  'Adjustment Disorders',
#  'Adlib Software',
#  'Admin Tools',
#  'Administered Payroll',
#  'Administering Blood Tests',
#  'Administering Cisco Unified Communications Manager And Unity Connection',
#  'Administering Emergency Oxygen',
#  'Administrative Law',
#  'Administrative Procedure Act',
#  'Admiralty Law',
#  'Admissions Operation',
#  'Admixtures',
#  'Admob',
#  'Adobe AIR',
#  'Adobe Acrobat',
#  'Adobe After Effects',
#  'Adobe Analytics',
#  'Adobe Audition',
#  'Adobe Authorware',
#  'Adobe Bridge',
#  'Adobe Captivate',
#  'Adobe ColdFusion',
#  'Adobe ColdFusion Builder',
#  'Adobe Connect',
#  'Adobe Content Servers',
#  'Adobe Contribute',
#  'Adobe CreatePDF',
#  'Adobe Creative Cloud',
#  'Adobe Creative Suite',
#  'Adobe Digital Editions',
#  'Adobe Director',
#  'Adobe Distiller',
#  'Adobe Dreamweaver',
#  'Adobe Edge Animate',
#  'Adobe Elearning Suite',
#  'Adobe Encore',
#  'Adobe Experience Manager',
#  'Adobe Fireworks',
#  'Adobe Flash',
#  'Adobe Flash Builder',
#  'Adobe Flash Catalyst',
#  'Adobe Flash Lite',
#  'Adobe Flash Media Servers',
#  'Adobe Flash Player',
#  'Adobe Flash Professional',
#  'Adobe Font Folio',
#  'Adobe FrameMaker',
#  'Adobe FreeHand',
#  'Adobe GoLive',
#  'Adobe Illustrator',
#  'Adobe ImageReady',
#  'Adobe InCopy',
#  'Adobe InDesign',
#  'Adobe JRun',
#  'Adobe Kuler',
#  'Adobe LiveCycle',
#  'Adobe LiveCycle Data Services',
#  'Adobe LiveMotion',
#  'Adobe Livecycle Designer',
#  'Adobe Marketing Cloud',
#  'Adobe PageMaker',
#  'Adobe PageMill',
#  'Adobe Persuasion',
#  'Adobe PhotoDeluxe',
#  'Adobe Photoshop',
#  'Adobe Photoshop Album',
#  'Adobe Photoshop Elements',
#  'Adobe Photoshop Lightroom',
#  'Adobe Premiere Elements',
#  'Adobe Premiere Pro',
#  'Adobe Presenter',
#  'Adobe RoboHelp',
#  'Adobe Shockwave',
#  'Adobe Soundbooth',
#  'Adobe Streamline',
#  'Adobe Technical Communication Suite',
#  'Adobe Type',
#  'Adobe Type Manager',
#  'Adobe Ultra',
#  'Adobe Version Cue',
#  'Adobe Visual Communicator',
#  'Adolescent Medicine',
#  'Adolescent Psychology',
#  'Adoptions',
#  'Adplus',
#  'Adserver',
#  'Adsorptions',
#  'Adult Cardiopulmonary Resuscitation',
#  'Adult Development',
#  'Adult Education',
#  'Adult Protective Services',
#  'Adult Trauma Life Support',
#  'AdvFS',
#  'Advance Design System',
#  'Advance Fire Fighting',
#  'Advance Ship Notice',
#  'Advanced Access Content Systems',
#  'Advanced Air Traffic Management Systems',
#  'Advanced Audio Coding',
#  'Advanced Authoring Format',
#  'Advanced Automatic Collision Notification',
#  'Advanced Boolean Expression Language',
#  'Advanced Burn Life Support',
#  'Advanced Business Application Programming',
#  'Advanced Business Language',
#  'Advanced Cardiovascular Life Support',
#  'Advanced Case Management',
#  'Advanced Chemistry Development',
#  'Advanced Civil Speed Enforcement Systems',
#  'Advanced Combat Direction Systems',
#  'Advanced Communication Server',
#  'Advanced Configuration And Power Interface',
#  'Advanced Continuous Simulation Languages',
#  'Advanced Deep Ocean Search Systems',
#  'Advanced Design Systems',
#  'Advanced Disaster Management',
#  'Advanced Distributed Learning',
#  'Advanced Distribution Automation',
#  'Advanced Driver Assistance Systems',
#  'Advanced Encryption Standard',
#  'Advanced Filter',
#  'Advanced Function Presentation',
#  'Advanced Function Presentation Data Stream',
#  'Advanced Gunnery Training System',
#  'Advanced Hazmat Life Support',
#  'Advanced Health Management Systems',
#  'Advanced Host Controller Interface',
#  'Advanced Imaging Technology',
#  'Advanced Inspection And Protection',
#  'Advanced Installer',
#  'Advanced Interactive Multidimensional Modeling System',
#  'Advanced Joint Effectiveness Model',
#  'Advanced Linux Sound Architecture',
#  'Advanced Logic',
#  'Advanced Manufacturing',
#  'Advanced Meat Recovery',
#  'Advanced Message Queuing Protocol',
#  'Advanced Microcontroller Bus Architecture',
#  'Advanced Packaging Tool',
#  'Advanced Process Control',
#  'Advanced Product Quality Planning',
#  'Advanced Queuing',
#  'Advanced RISC Computing',
#  'Advanced Rest Client',
#  'Advanced SCSI Programming Interface',
#  'Advanced Search Advertising',
#  'Advanced Search Engine Optimization',
#  'Advanced Stream Redirector',
#  'Advanced Technical Information System',
#  'Advanced Television',
#  'Advanced Television Systems Committee - Mobile/Handheld  Standard',
#  'Advanced Traffic Management Systems',
#  'Advanced Train Control System',
#  'Advanced Trauma Care For Nurses',
#  'Advanced Trauma Life Support',
#  'Advanced Video Coding High Definition',
#  'Advanced Volatile Threat',
#  'Advantage Database Servers',
#  'Adventure Education',
#  'Adventure Game Studio',
#  'Adventure Therapy',
#  'Adverse Drug Reactions',
#  'Adverse Event Monitoring',
#  'Adverse Possession',
#  'Advertisement',
#  'Advertising Campaigns',
#  'Advertising Mail',
#  'Advertising Management',
#  'Advertising Networks',
#  'Advertising Sales',
#  'Advertorials',
#  'Adview',
#  'Advising',
#  'Advisories',
#  'Advisory Circular',
#  'Advisory Work',
#  'Advocacy Journalism',
#  'Adware',
#  'Aegis Ballistic Missile Defense Systems',
#  'Aegisub',
#  'Aerated Lagoon',
#  'Aeration',
#  'Aeration Systems',
#  'Aerators',
#  'Aerial Cable',
#  'Aerial Firefighting',
#  'Aerial Lifts',
#  'Aerial Photography',
#  'Aerial Reconnaissance',
#  'Aerial Refueling',
#  'Aerial Surveys',
#  'Aerial Work Platforms',
#  'Aerobic Conditioning',
#  'Aerobic Exercises',
#  'Aerobic Kickboxing',
#  'Aerobic Organisms',
#  'Aerobics',
#  'Aerobiological Engineering',
#  'Aerodrome Mapping Databases',
#  'Aerodynamic Heating',
#  'Aerodynamics',
#  'Aeromagnetic Survey',
#  'Aeronautical Fixed TeleCommunication Networks',
#  'Aeronautical Information Service',
#  'Aeronautical Message Handling Systems',
#  'Aerosol Science',
#  'Aerosols',
#  'Aerospace Basic Quality System Standards',
#  'Aerospace Engineering',
#  'Aerospace Industry',
#  'Aerospace Materials',
#  'Aerospace Physiology',
#  'Aerospike',
#  'Aerostructure',
#  'Aesthetic Medicine',
#  'Affiliate Marketing',
#  'Affiliate Networks',
#  'Affinity Chromatography',
#  'Affinity Marketing',
#  'Affirmative Defense',
#  'Affymetrix GeneChip Operating Software',
#  'Aforge',
#  'African Dances',
#  'African Studies',
#  'Afterburner',
#  'Aftercare',
#  'Aftermarket Modifications',
#  'Aftersales',
#  'Agarose Gel Electrophoresis',
#  'Agency Law',
#  'Agent Extensibility Protocols',
#  'Agent-Based Model',
#  'Agentsheets',
#  'AggFlow',
#  'Agglutination',
#  'Aggregate Functions',
#  'Aggregate Level Simulation Protocol',
#  'Aggregate Planning',
#  'Aggregation Analysis',
#  'Aggregator',
#  'Aggression Replacement Training',
#  'Agile Central',
#  'Agile Edge Technologies',
#  'Agile Leadership',
#  'Agile Management',
#  'Agile Model Driven Development',
#  'Agile Modeling',
#  'Agile Software Development',
#  'Agile Testing',
#  'Agile Unified Process',
#  'Agilefant',
#  'Agilent ChemStation',
#  'Agilent VEE',
#  'Agility',
#  'Agility CMS',
#  'Aging Processes',
#  'Agrep',
#  'Agribusiness',
#  'Agricultural Chemicals',
#  'Agricultural Chemistry',
#  'Agricultural Commodities',
#  'Agricultural Consumer And Environmental Sciences',
#  'Agricultural Economics',
#  'Agricultural Education',
#  'Agricultural Engineering',
#  'Agricultural Machinery',
#  'Agricultural Microbiology',
#  'Agricultural Modeling And Training Systems',
#  'Agricultural Productivity',
#  'Agriculture',
#  'Agrobacterium',
#  'Agrochemicals',
#  'Agroinfiltration',
#  'Ahrefs Site Explorer',
#  'Aikido',
#  'Aimaq Dialects',
#  'Ainu',
#  'Air And Ocean Freight Forwarding',
#  'Air Assault',
#  'Air Brakes',
#  'Air Brush',
#  'Air Carbon Arc',
#  'Air Carbon Arc Cutting',
#  'Air Cargos',
#  'Air Distribution Service Technician',
#  'Air Filters',
#  'Air Flow Tests',
#  'Air Force Equipment Management Systems',
#  'Air Force Satellite Control Networks',
#  'Air Hammers',
#  'Air Handler',
#  'Air Navigation',
#  'Air Pollution Control',
#  'Air Purge Systems',
#  'Air Quality',
#  'Air Quality Control',
#  'Air Routing International',
#  'Air Stripping',
#  'Air Traffic Control',
#  'Air-Cooled Engines',
#  'Air-Operated Valve',
#  'AirSnort',
#  'Airborne Warning And Control Systems',
#  'Airbox',
#  'Airbrush Makeup',
#  'Aircrack-Ng',
#  'Aircraft Assembly',
#  'Aircraft Communication Addressing And Reporting Systems',
#  'Aircraft Design',
#  'Aircraft Electronics',
#  'Aircraft Handler',
#  'Aircraft Interiors',
#  'Aircraft Inventory And Readiness Reporting System',
#  'Aircraft Maintenance',
#  'Aircraft Records',
#  'Aircraft Seats',
#  'Aircraft Technology',
#  'Aircraft Weapons',
#  'Airflow',
#  'Airguard',
#  'Airline Catering',
#  'Airline Economics',
#  'Airline Reservations Systems',
#  'Airman Leadership',
#  'Aironet Wireless Communications',
#  'Airplay',
#  'Airplay SDK',
#  'Airport Authorities',
#  'Airport Concessions Disadvantaged Business Enterprise',
#  'Airport Express',
#  'Airport Movement Area Safety Systems',
#  'Airport Transportation',
#  'Airprint',
#  'Airspace',
#  'Airwatch',
#  'Airway Management',
#  'Airway-Breathing-Compressions',
#  'Airworthiness',
#  'Airworthiness Certificate',
#  'Ajax',
#  'Ajax.net',
#  'Ajax4jsf',
#  'Akamai',
#  'Akan',
#  'Akka',
#  'Akka.net',
#  'Akkadian Language',
#  'Alamofire',
#  'Alarm Devices',
#  'Alarm Indication Signal',
#  'Alarm Management',
#  'Alarm Monitoring',
#  'Alasset',
#  'Alchemy Catalyst',
#  'Alcohol Education',
#  'Alcoholic Liver Disease',
#  'Aldus PhotoStyler',
#  'Alembics',
#  'Alfresco ECM',
#  'Algae',
#  'Algaecide',
#  'Algebra',
#  'Algebraic Logic Functional',
#  'Algebraic Modeling Language',
#  'Algolia',
#  'Algorithm Design',
#  'Algorithmic Trading',
#  'Algorithms',
#  'Aliasing',
#  'Alibre Design',
#  'Alimony',
#  'Alivepdf',
#  'Alkaline Lysis',
#  'Alkalinity Tests',
#  'Alkalis',
#  'Alkylation Units',
#  'All Terrain Vehicles',
#  'All Wheel Drive',
#  'Allegro Common Lisp',
#  'AllegroGraph',
#  'Allergen Immunotherapy',
#  'Allergens',
#  'Allergology',
#  'Allergy Testing',
#  'Allianz Global Assistance',
#  'AlliedWare Plus',
#  'Alljoyn',
#  'Allogenetics',
#  'Allowable Strength Design',
#  'Allway Sync',
#  'Alpha Hydroxy Acid',
#  'AlphaBasic',
#  'AlphaServer',
#  'Altap Salamander',
#  'Altera Hardware Description Language',
#  'Altera Quartus',
#  'Alterations',
#  'Alternate Fuels Technician',
#  'Alternating Bit Protocol',
#  'Alternating Current',
#  'Alternative Education',
#  'Alternative Financial Services',
#  'Alternative Fuels',
#  'Alternative Investment Strategies',
#  'Alternative Investments',
#  'Alternative Lending',
#  'Alternative Medicine',
#  'Alternative Rendering Framework',
#  'Alternative Technologies',
#  'Alternative Therapies',
#  'Alternative Trading Systems',
#  'Alternative Transients Program',
#  'Alternators',
#  'Alteryx',
#  'AltiVec',
#  'Altia - User Interface Design Tools And GUI Software',
#  'Altitudes',
#  'Altium Designer',
#  'Altix Supercomputers',
#  'Altova DiffDog',
#  'Aluminium Smelting',
#  'Aluminium-Conductor Steel-Reinforced Cabling',
#  'Aluminum',
#  'Aluminum Wires',
#  "Alzheimer's Disease",
#  'Amadeus CRS',
#  'Amavis',
#  'Amazon Alexa',
#  'Amazon AppStore',
#  'Amazon Cloud Drive',
#  'Amazon CloudSearch',
#  'Amazon Cloudfront',
#  'Amazon DynamoDB',
#  'Amazon ElastiCache',
#  'Amazon Elastic Block Stores',
#  'Amazon Elastic Compute Cloud',
#  'Amazon Emr',
#  'Amazon Flexible Payments Services',
#  'Amazon Marketplace',
#  'Amazon Mechanical Turk',
#  'Amazon Product Advertising API',
#  'Amazon Redshift',
#  'Amazon Relational Database Services',
#  'Amazon S3',
#  'Amazon Simple Notification Service',
#  'Amazon Simple Queue Services',
#  'Amazon Simpledb',
#  'Amazon Web Services',
#  'Ambari',
#  'Ambulances',
#  'Ambulatory Blood Pressure Monitoring',
#  'Ambulatory Care',
#  'Ambulatory Care Nursing',
#  'Ambulatory Care Pharmacy',
#  'Ambulatory Phlebectomy',
#  'Ambush Marketing',
#  'Amcharts',
#  'Amd Processor',
#  "America's Labor Market Information Systems",
#  'American Association Of Pharmaceutical Scientists',
#  'American Culinary Federation',
#  'American Customer Satisfaction Index',
#  'American Football',
#  'American Institute Of Architects',
#  'American Jurisprudence',
#  'American Medical Billing Association',
#  'American Psychological Style',
#  'American Recovery And Reinvestment Act',
#  'American Society For Investigative Pathology',
#  'American Standard Code For Information Interchange',
#  'American Welding Society Codes',
#  'Americans With Disabilities Act Amendments Act',
#  'Americas Region Caribbean Ring System',
#  'AmfPHP',
#  'Amharic Language',
#  'Amiga',
#  'AmigaBASIC',
#  'AmigaDOS',
#  'AmigaOS',
#  'Amine Gas Treating',
#  'Amino Acids',
#  'Ammonia',
#  'Ammoniacal Nitrogen',
#  'Ammunitions',
#  'Amniocentesis',
#  'Amortization',
#  'Amortization Schedule',
#  'Amperometry',
#  'AmpliTube',
#  'Amplified Fragment Length Polymorphism',
#  'Amplifyjs',
#  'Amplitude Modulation Signalling Systems',
#  'Amplitude Versus Offset',
#  'Amplitudes',
#  'Ampps',
#  'Amputation',
#  'Amygdalae',
#  'Amyotrophic Lateral Sclerosis',
#  'Anaerobic Organisms',
#  'Anaglyph 3D',
#  'Analgesics',
#  'Analog Devices',
#  'Analog Filters',
#  'Analog Photography',
#  'Analog Recording',
#  'Analog Signal Processing',
#  'Analog Signature Analysis',
#  'Analog Transmission',
#  'Analog-To-Digital Converters',
#  'Analogue Electronics',
#  'Analysis Integration And Modeling Of The Earth System',
#  'Analysis Of Algorithms',
#  'Analysis Of Covariance',
#  'Analysis Of Functional NeuroImages',
#  'Analysis Of Variance',
#  'Analytic Applications',
#  'Analytic Functions',
#  'Analytic Geometry',
#  'Analytic Hierarchy Process',
#  'Analytical Chemistry',
#  'Analytical Mechanics',
#  'Analytical Procedures',
#  'Analytical Psychology',
#  'Analytical Techniques',
#  'Analytics',
#  'Analytics.js',
#  'Anam',
#  'Anaphylaxis',
#  'Anatomical Pathology',
#  'Anatomy',
#  'Anchoring',
#  'Ancient Greek',
#  'Ancillary Function Driver',
#  'Andengine',
#  'Andragogy',
#  'Android ButterKnife',
#  'Android Cloud To Device Messaging Services',
#  'Android Debug Bridge',
#  'Android Interface Definition Language',
#  'Android Marshmallow',
#  'Android NDK',
#  'Android Software Development',
#  'Android Studio',
#  'Android Ui',
#  'Andrology',
#  ...]

# %%
def preprocess_skills(value_list):
    # Define the pattern to match special characters
    special_char = ['#', '+']
    cleaned_values = [re.sub(r'[^a-zA-Z0-9{}]+'.format(re.escape(' '.join(special_char))), ' ', value) for value in value_list]
    return cleaned_values

skill_list = preprocess_skills(skill_list)

# %%
#Creating all the possible grams for each sentence
allgrams = []

#This tokenizer immediately removes punctuation and special characters from the sentence
tokenizer = RegexpTokenizer(r'\w+')

#,sentence,sentence_lemmatized,sentence_no_stopwords

for sentence in tqdm(df1['sentence']):
    tokenizedsentence = tokenizer.tokenize(str(sentence))
    
    #Getting all possible n grams of the sentence
    #for n in range(1,len(tokenizedsentence)+1):
    
    #getting up to four grams for each sentence
    for n in range(1,5):
        grams = ngrams(tokenizedsentence,n)
        for gram in grams:
            allgrams.append(str(gram))

allgrams = pd.DataFrame(allgrams)
allgrams = allgrams.rename(columns={0:'allgrams'})
print(allgrams.shape[0])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 17602/17602 [00:03<00:00, 5079.47it/s]
# 1041064

# %%
#Initializing the keyword processor
keyword_processor = KeywordProcessor(case_sensitive=False)

#Adding all the skills to the processor
for skill in tqdm(skill_list):
    keyword_processor.add_keyword(skill)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 28441/28441 [00:00<00:00, 29190.39it/s]

# %%
def searcher(row):
    #check if the words are in the row and return a True or False instead of the actual word
    boolean = bool(keyword_processor.extract_keywords(row))
    return boolean

tqdm.pandas()
allgrams['contains_skill'] = allgrams['allgrams'].progress_apply(searcher)

#Only selecting the ngrams which contain a skill
allgrams = allgrams[allgrams.contains_skill == True]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 1041064/1041064 [00:33<00:00, 30673.28it/s]

# %%
allgrams = allgrams[allgrams.contains_skill == True]
allgrams = allgrams.drop(columns=['contains_skill'])
allgrams.dropna(subset=['allgrams'],inplace=True)

# %%
allgrams['allgrams'] = allgrams['allgrams'].astype(str)
allgrams['allgrams'] = allgrams['allgrams'].str.replace(r"[(),.']", '')
allgrams['allgrams'] = allgrams['allgrams'].str.strip()
allgrams
# Out:
# C:\Users\Kelly Chin\AppData\Local\Temp\ipykernel_57128\1864550597.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   allgrams['allgrams'] = allgrams['allgrams'].str.replace(r"[(),.']", '')
#                                      allgrams
# 12                                     source
# 31                              export source
# 32                             source systems
# 49                       import export source
# 50                      export source systems
# ...                                       ...
# 1040798           nlp good programming skills
# 1040799        good programming skills python
# 1040800  programming skills python references
# 1040801     skills python references xiachong
# 1040802       python references xiachong feng
#
# [169575 rows x 1 columns]

# %%
matcher1 = PhraseMatcher(nlp.vocab)
#Adding all the trigrams to the matcher
for gram in tqdm(allgrams['allgrams']):
    matcher1.add("NGRAM", [nlp(gram)])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 169575/169575 [29:02<00:00, 97.32it/s]

# %%
leftcontextstorage = []
recoveredgramstorage = []
rightcontextstorage = []

for sentence in tqdm(df1['sentence']):

    #Intiatilizing the sentence and searching for matches
    doc = nlp(sentence)
    matches = matcher1(doc)

    for match_id, start, end in matches:
        
        #Getting up to 5 contextwords next to the grams
        for contextnumbers in range(1,6,1):

            #Defining the number of context words
            leftcontextnumbers = contextnumbers
            rightcontextnumbers = contextnumbers

            #Checking if there is any context to the left or right of the gram, if not skipping the gram
            if start == 0 or end == len(doc):
                continue

            #Checking if there is enough context to the left of the gram
            if start < leftcontextnumbers:
                leftcontextnumbers = start
            #Checking if there is enough context to the right of the gram
            elif end+rightcontextnumbers > len(doc):
                rightcontextnumbers = len(doc)-end

            # Get the left context of the gram
            leftcontext = doc[start-leftcontextnumbers:start]
            # Get the recovered gram by slicing the Doc 
            recoveredgram = doc[start:end]
            # Get the right context of the gram
            rightcontext = doc[end:(end+rightcontextnumbers)]


            leftcontextstorage.append(leftcontext.text)
            recoveredgramstorage.append(recoveredgram.text)
            rightcontextstorage.append(rightcontext.text)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 17602/17602 [03:33<00:00, 82.36it/s]

# %%
df2 = pd.DataFrame(zip(leftcontextstorage,recoveredgramstorage,rightcontextstorage),
                 columns=['left_context', 'candidate_skill', 'right_context'])
df2
# Out:
#                                   left_context  \
# 0                                         data
# 1                                     end data
# 2                                 end end data
# 3                      facilitate end end data
# 4            pipelines facilitate end end data
# ...                                        ...
# 751330                                  skills
# 751331                      programming skills
# 751332                 good programming skills
# 751333             nlp good programming skills
# 751334  approaches nlp good programming skills
#
#                         candidate_skill                          right_context
# 0             flow import export source                                systems
# 1             flow import export source                           systems data
# 2             flow import export source                 systems data warehouse
# 3             flow import export source         systems data warehouse reports
# 4             flow import export source  systems data warehouse reports models
# ...                                 ...                                    ...
# 751330  python references xiachong feng                              xiaocheng
# 751331  python references xiachong feng                         xiaocheng feng
# 751332  python references xiachong feng                    xiaocheng feng bing
# 751333  python references xiachong feng                xiaocheng feng bing qin
# 751334  python references xiachong feng         xiaocheng feng bing qin survey
#
# [751335 rows x 3 columns]

# %%
df2['concatenated'] = df2['left_context'] + ' | ' + df2['candidate_skill'] + ' | ' + df2['right_context']
df2['label'] = ""
df2
# Out:
#                                   left_context  \
# 0                                         data
# 1                                     end data
# 2                                 end end data
# 3                      facilitate end end data
# 4            pipelines facilitate end end data
# ...                                        ...
# 751330                                  skills
# 751331                      programming skills
# 751332                 good programming skills
# 751333             nlp good programming skills
# 751334  approaches nlp good programming skills
#
#                         candidate_skill  \
# 0             flow import export source
# 1             flow import export source
# 2             flow import export source
# 3             flow import export source
# 4             flow import export source
# ...                                 ...
# 751330  python references xiachong feng
# 751331  python references xiachong feng
# 751332  python references xiachong feng
# 751333  python references xiachong feng
# 751334  python references xiachong feng
#
#                                 right_context  \
# 0                                     systems
# 1                                systems data
# 2                      systems data warehouse
# 3              systems data warehouse reports
# 4       systems data warehouse reports models
# ...                                       ...
# 751330                              xiaocheng
# 751331                         xiaocheng feng
# 751332                    xiaocheng feng bing
# 751333                xiaocheng feng bing qin
# 751334         xiaocheng feng bing qin survey
#
#                                              concatenated label
# 0              data | flow import export source | systems
# 1       end data | flow import export source | systems...
# 2       end end data | flow import export source | sys...
# 3       facilitate end end data | flow import export s...
# 4       pipelines facilitate end end data | flow impor...
# ...                                                   ...   ...
# 751330  skills | python references xiachong feng | xia...
# 751331  programming skills | python references xiachon...
# 751332  good programming skills | python references xi...
# 751333  nlp good programming skills | python reference...
# 751334  approaches nlp good programming skills | pytho...
#
# [751335 rows x 5 columns]

# %%
final_df = df2.sample(n=2000,random_state=200)
final_df
# Out:
#                                     left_context  \
# 168421                           answer specific
# 106851                              docker nginx
# 108999        etl software informatica oracle pl
# 744355                                        cv
# 423826                              data science
# ...                                          ...
# 581231                                   data ai
# 584628  data architects biostatisticians advance
# 292184       analyze data knowledge create apply
# 275398                               designation
# 422623                learning models pandas git
#
#                              candidate_skill  \
# 168421        business questions identifying
# 106851                                   sql
# 108999                         sql scripting
# 744355              standard chartered we re
# 423826                     coe leverage huge
# ...                                      ...
# 581231                 analytics initiatives
# 584628  quality information derived existing
# 292184                   accurate algorithms
# 275398                  finance data analyst
# 422623                 bash scripting growth
#
#                                   right_context  \
# 168421                             calling data
# 106851                          nosql databases
# 108999             sql scripting unix scripting
# 744355                            international
# 423826                       volumes structured
# ...                                         ...
# 581231                  collaboration divisions
# 584628                       clinical databases
# 292184  datasets ability work effectively teams
# 275398      responsibilities extract clean data
# 422623                                  mindset
#
#                                              concatenated label
# 168421  answer specific | business questions identifyi...
# 106851               docker nginx | sql | nosql databases
# 108999  etl software informatica oracle pl | sql scrip...
# 744355      cv | standard chartered we re | international
# 423826  data science | coe leverage huge | volumes str...
# ...                                                   ...   ...
# 581231  data ai | analytics initiatives | collaboratio...
# 584628  data architects biostatisticians advance | qua...
# 292184  analyze data knowledge create apply | accurate...
# 275398  designation | finance data analyst | responsib...
# 422623  learning models pandas git | bash scripting gr...
#
# [2000 rows x 5 columns]

# %%
final_df.to_csv("final2000.csv",
          index=False)
df2.to_csv("final_full.csv",
          index=False)
